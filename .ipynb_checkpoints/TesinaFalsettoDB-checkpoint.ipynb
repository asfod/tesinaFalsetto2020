# %%
library(seewave)
library(tuneR)
library(fftw)

normalize <- function(x) {
    return ((x-min(x))/(max(x)-min(x)))
}
filelist <- list.files(pattern = '.*.wav')
label='falsetto'
df <- data.frame(meanfreq=numeric(),sd=numeric(),median=numeric(),Q25=numeric(),Q75=numeric(),IQR=numeric(),skew=numeric(),kurt=numeric(),sp.ent=numeric(),sfm=numeric(),mode=numeric(),centroid=numeric(),meanfun=numeric(),minfun=numeric(),maxfun=numeric(),meandom=numeric(),mindom=numeric(),maxdom=numeric(),dfrange=numeric(),modindx=numeric(),label=character(), stringsAsFactors = FALSE)
#cbind(df,list(meanfreq=numeric(),sd=numeric(),median=numeric(),Q25=numeric(),Q75=numeric(),IQR=numeric(),skew=numeric(),kurt=numeric(),sp.ent=numeric(),sfm=numeric(),mode=numeric(),centroid=numeric(),peakf=numeric(),meanfun=numeric(),minfun=numeric(),maxfun=numeric(),meandom=numeric(),mindom=numeric(),maxdom=numeric(),dfrange=numeric(),label=character()))
for(file in filelist) {
    wavObj <- readWave(file)
    samplespec <- spec(wavObj, f = wavObj@samp.rate, plot = F)
    sp <- specprop(samplespec, f = wavObj@samp.rate, flim = c(0, 280/1000), plot = F)
    
    ff <- fund(wavObj, f = wavObj@samp.rate, ovlp = 50, threshold = 5, fmax = 280, ylim=c(0, 280/1000), plot = FALSE, wl = 2048)[, 2]
    meanfun <- mean(ff, na.rm = TRUE)
    minfun <- min(ff, na.rm = TRUE)
    maxfun <-max(ff, na.rm = TRUE)
    
    y <- dfreq(wavObj, f = wavObj@samp.rate, wl = 2048, ylim=c(0, 280/1000), ovlp = 0, plot = F, threshold = 5, bandpass = c(0,22) * 1000, fftw = TRUE)[,2]
    meandom <- mean(y, na.rm = TRUE)
    mindom <- min(y, na.rm = TRUE)
    maxdom <- max(y, na.rm = TRUE)
    dfrange <- (maxdom - mindom)
    
    #Calculate modindx
    changes <- vector()
    for(j in which(!is.na(y))){
      change <- abs(y[j] - y[j + 1])
      changes <- append(changes, change)
    }
    if(mindom==maxdom) modindx<-0 else modindx <- mean(changes, na.rm = T)/dfrange
    
    

    
    #fp <- fpeaks(a, nmax=1); #dominant frequency: two column matrix, x and y coordinates (frequency in fp[1])
    df <- rbind(df,list(meanfreq=sp$mean/1000,sd=sp$sd/1000,median=sp$median/1000,Q25=sp$Q25/1000,Q75=sp$Q75/1000,IQR=sp$IQR/1000,skew=sp$skewness,kurt=sp$kurtosis,sp.ent=sp$sh,sfm=sp$sfm,mode=sp$mode/1000,centroid=sp$cent/1000,meanfun=meanfun,minfun=minfun,maxfun=maxfun,meandom=meandom,maxdom=maxdom,mindom=mindom,dfrange=dfrange,modindx=modindx,label=label))
}
# Out:
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”
# Warning message in (0:(n - 1)) * f:
# “NAs produced by integer overflow”

# %%
df
# Out:
#      meanfreq   sd         median     Q25        Q75       IQR
# 1    0.16687246 0.10109177 0.20191063 0.05824345 0.2648998 0.20665639
# 2    0.22468144 0.04145300 0.23146159 0.20823929 0.2537322 0.04549286
# 3    0.22466803 0.07217859 0.26153846 0.20153846 0.2730769 0.07153846
# 4    0.22637665 0.06134427 0.25182927 0.20800813 0.2680488 0.06004065
# 2041 0.03477918 0.2722222 1.1789429  2.2179199 0.7536621  1.46425781 0.33088235
#      label
# 1    falsetto
# 2    falsetto
# 3    falsetto
# 4    falsetto
# 5    falsetto
# 6    falsetto
# 7    falsetto
# 8    falsetto
# 9    falsetto
# 10   falsetto
# 11   falsetto
# 12   falsetto
# 13   falsetto
# 14   falsetto
# 15   falsetto
# 16   falsetto
# 17   falsetto
# 18   falsetto
# 19   falsetto
# 20   falsetto
# 21   falsetto
# 22   falsetto
# 23   falsetto
# 24   falsetto
# 25   falsetto
# 26   falsetto
# 27   falsetto
# 28   falsetto
# 29   falsetto
# 30   falsetto
# ⋮    ⋮
# 2012 falsetto
# 2013 falsetto
# 2014 falsetto
# 2015 falsetto
# 2016 falsetto
# 2017 falsetto
# 2018 falsetto
# 2019 falsetto
# 2020 falsetto
# 2021 falsetto
# 2022 falsetto
# 2023 falsetto
# 2024 falsetto
# 2025 falsetto
# 2026 falsetto
# 2027 falsetto
# 2028 falsetto
# 2029 falsetto
# 2030 falsetto
# 2031 falsetto
# 2032 falsetto
# 2033 falsetto
# 2034 falsetto
# 2035 falsetto
# 2036 falsetto
# 2037 falsetto
# 2038 falsetto
# 2039 falsetto
# 2040 falsetto
# 2041 falsetto

# %%
head(df)
# Out:
#   meanfreq  sd         median    Q25        Q75       IQR        skew
# 1 0.1668725 0.10109177 0.2019106 0.05824345 0.2648998 0.20665639 3.868133
# 2 0.2246814 0.04145300 0.2314616 0.20823929 0.2537322 0.04549286 1.744928
# 3 0.2246680 0.07217859 0.2615385 0.20153846 0.2730769 0.07153846 4.551774
# 4 0.2263767 0.06134427 0.2518293 0.20800813 0.2680488 0.06004065 3.450947
# 5 0.2200047 0.06515694 0.2471174 0.18633452 0.2680427 0.08170819 2.955386
# 6 0.2293692 0.06189719 0.2565517 0.21399015 0.2709360 0.05694581 3.800853
#   kurt      sp.ent    sfm       ⋯ centroid  meanfun   minfun     maxfun
# 1 21.901559 0.9238666 0.6288677 ⋯ 0.1668725 0.1361510 0.04427711 0.2791139
# 2  5.834798 0.8854254 0.2654325 ⋯ 0.2246814 0.1489176 0.04701273 0.2790698
# 3 26.346689 0.8235295 0.4118632 ⋯ 0.2246680 0.1353718 0.04958678 0.2758621
# 4 17.360001 0.8720069 0.4016159 ⋯ 0.2263767 0.1276312 0.04761905 0.2790698
# 5 12.813220 0.8707420 0.4642886 ⋯ 0.2200047 0.1068580 0.04795205 0.2181818
# 6 19.031959 0.8695985 0.3953094 ⋯ 0.2293692 0.1185999 0.04705882 0.2622951
#   meandom   maxdom    mindom   dfrange   modindx    label
# 1 0.6112793 3.0361816 0.000000 3.0361816 0.09868719 falsetto
# 2 0.3913741 3.4921875 0.000000 3.4921875 0.04500592 falsetto
# 3 0.3921875 2.6953125 0.234375 2.4609375 0.07914614 falsetto
# 4 0.8717731 5.5546875 0.000000 5.5546875 0.07534659 falsetto
# 5 0.5604620 4.6406250 0.281250 4.3593750 0.05913978 falsetto
# 6 0.4421875 0.9609375 0.000000 0.9609375 0.09629941 falsetto

# %%
#write.csv(df, "falsetto_augmented.csv")
